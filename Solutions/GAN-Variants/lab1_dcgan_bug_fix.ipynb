# %% [markdown]
# # DCGAN — Bug-Fix Labs - 10 Bugs

# %%
import torch, torchvision
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# ---------------------------
# Data
# ---------------------------
transform = transforms.Compose([
    transforms.Resize(32),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # BUG: Add normalization to the RGB image ("No pre-processing was applied to training images besides scaling to the range of the tanh activation function [-1, 1]"")
])
ds = torchvision.datasets.CIFAR10('./data', train=True, download=True, transform=transform)
loader = DataLoader(ds, batch_size=128, shuffle=True, num_workers=2, pin_memory=True)

# %%
# ---------------------------
# Hyperparams
# ---------------------------
z_dim = 100
g_lr  = 2e-4   # BUG: fix learning rate based
d_lr  = 2e-4

# %%
# ---------------------------
# Models
# ---------------------------
class D(nn.Module):
    def __init__(self, ch=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, ch,   4, 2, 1),
            nn.BatchNorm2d(ch),
            nn.LeakyReLU(0.2,inplace=True),         # BUG
            nn.Conv2d(ch, ch*2, 4, 2, 1),
            nn.BatchNorm2d(ch*2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ch*2, ch*4, 4, 2, 1),
            nn.BatchNorm2d(ch*4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(ch*4, 1,    4, 1, 0),
            #nn.Sigmoid()                   # BUG: since we are using BCE with logits outputs, we don't need to have sigmoid here since it is already used internally by the loss func
        )
    def forward(self, x):
        return self.net(x).view(x.size(0))

class G(nn.Module):
    def __init__(self, z=100, ch=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.ConvTranspose2d(z,   ch*4, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ch*4), nn.ReLU(True),
            nn.ConvTranspose2d(ch*4, ch*2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ch*2), nn.ReLU(True),
            nn.ConvTranspose2d(ch*2, ch,   4, 2, 1, bias=False),
            nn.BatchNorm2d(ch),   nn.ReLU(True),
            nn.ConvTranspose2d(ch,  3,     4, 2, 1, bias=False),
            # BUG: add tanh as an activation function in the end of the G
            nn.Tanh()
        )
    def forward(self, z):
        z = z.view(z.size(0), z_dim, 1, 1)   # BUG: the z_dim should be used here, instead of 64
        return self.net(z)

Dnet = D().to(device)
Gnet = G(z_dim).to(device)

# %%
# ---------------------------
# Loss & Optimizers
# ---------------------------
crit = nn.BCEWithLogitsLoss()             # using logits loss → D must NOT have Sigmoid
opt_d = torch.optim.Adam(Dnet.parameters(), lr=d_lr, betas=(0.5, 0.999))
opt_g = torch.optim.Adam(Gnet.parameters(), lr=g_lr,  betas=(0.5, 0.999))

# %%
# ---------------------------
# Training (intentionally wrong)
# ---------------------------
epochs = 10 # Define number of epochs for training
for epoch in range(epochs):
    for i, (real, _) in enumerate(loader):
        real = real.to(device)
        b = real.size(0)

        # ---- Discriminator step ----
        z = torch.randn(b, z_dim, device=device)
        fake = Gnet(z).detach()                         # BUG: apply detach to remove the gradient graph

        Dnet.zero_grad()                                # (missing) zero the gradients for D
        # BUG: fix the target labels by switching ones and zeros
        loss_d = crit(Dnet(real), torch.ones(b, device=device)) + \
                 crit(Dnet(fake), torch.zeros (b, device=device))

        loss_d.backward()
        opt_d.step()                           # BUG: replace opt_g with _d

        # ---- Generator step ----
        z = torch.randn(b, z_dim, device=device)
        fake = Gnet(z)
        opt_g.zero_grad()                                # (missing) zero the gradients for G
        # BUG
        loss_g = crit(Dnet(fake), torch.ones(b, device=device)) # BUG: G wants D to output 1 for fake images
        loss_g.backward()
        opt_g.step()
        opt_g.zero_grad()

        # print error
        if i % 100 == 0: # Print every 100 batches
            print(f"Epoch [{epoch}/{epochs}] Batch [{i}/{len(loader)}] Loss D: {loss_d.item():.4f}, Loss G: {loss_g.item():.4f}")


    # (missing) Add logging or visualization of generated images
    # (missing) Save model checkpoints

print("Your task: fix all 10 bugs until training runs and samples look reasonable.")
# Out:
# Epoch [0/10] Batch [0/391] Loss D: 1.4099, Loss G: 1.3847
# Epoch [0/10] Batch [100/391] Loss D: 0.1905, Loss G: 5.8400
# Epoch [0/10] Batch [200/391] Loss D: 0.4174, Loss G: 2.5853
# Epoch [0/10] Batch [300/391] Loss D: 0.4129, Loss G: 6.9250
# Epoch [1/10] Batch [0/391] Loss D: 0.2288, Loss G: 3.9677
# Epoch [1/10] Batch [100/391] Loss D: 0.2429, Loss G: 4.4842
# Epoch [1/10] Batch [200/391] Loss D: 0.2296, Loss G: 3.9257
# Epoch [1/10] Batch [300/391] Loss D: 0.2277, Loss G: 2.9052
# Epoch [2/10] Batch [0/391] Loss D: 0.5079, Loss G: 2.3634
# Epoch [2/10] Batch [100/391] Loss D: 0.3655, Loss G: 2.6611
# Epoch [2/10] Batch [200/391] Loss D: 0.5376, Loss G: 3.7566
# Epoch [2/10] Batch [300/391] Loss D: 0.3551, Loss G: 3.0611
# Epoch [3/10] Batch [0/391] Loss D: 0.5221, Loss G: 5.3733
# Epoch [3/10] Batch [100/391] Loss D: 0.4149, Loss G: 4.2857
# Epoch [3/10] Batch [200/391] Loss D: 1.4608, Loss G: 3.8499
# Epoch [3/10] Batch [300/391] Loss D: 0.2689, Loss G: 2.9956
# Epoch [4/10] Batch [0/391] Loss D: 0.3033, Loss G: 2.8237
# Epoch [4/10] Batch [100/391] Loss D: 1.1565, Loss G: 1.8939
# Epoch [4/10] Batch [200/391] Loss D: 0.4126, Loss G: 3.7309
# Epoch [4/10] Batch [300/391] Loss D: 0.3791, Loss G: 3.2319
# Epoch [5/10] Batch [0/391] Loss D: 0.4853, Loss G: 3.5222
# Epoch [5/10] Batch [100/391] Loss D: 0.5855, Loss G: 2.8984
# Epoch [5/10] Batch [200/391] Loss D: 0.3489, Loss G: 2.9727
# Epoch [5/10] Batch [300/391] Loss D: 0.4363, Loss G: 2.7290
# Epoch [6/10] Batch [0/391] Loss D: 0.3247, Loss G: 3.3932
# Epoch [6/10] Batch [100/391] Loss D: 0.5510, Loss G: 2.9482
# Epoch [6/10] Batch [200/391] Loss D: 0.4003, Loss G: 2.4762
# Epoch [6/10] Batch [300/391] Loss D: 0.3610, Loss G: 1.6356
# Epoch [7/10] Batch [0/391] Loss D: 0.4105, Loss G: 2.2605
# Epoch [7/10] Batch [100/391] Loss D: 0.3558, Loss G: 2.7297
# Epoch [7/10] Batch [200/391] Loss D: 0.3899, Loss G: 2.4908
# Epoch [7/10] Batch [300/391] Loss D: 0.3852, Loss G: 2.4826
# Epoch [8/10] Batch [0/391] Loss D: 0.5158, Loss G: 1.8348
# Epoch [8/10] Batch [100/391] Loss D: 0.6303, Loss G: 1.4141
# Epoch [8/10] Batch [200/391] Loss D: 0.3865, Loss G: 2.5475
# Epoch [8/10] Batch [300/391] Loss D: 0.3714, Loss G: 2.2013
# Epoch [9/10] Batch [0/391] Loss D: 0.5004, Loss G: 2.7147
# Epoch [9/10] Batch [100/391] Loss D: 0.3685, Loss G: 3.4010
# Epoch [9/10] Batch [200/391] Loss D: 0.3013, Loss G: 2.9080
# Epoch [9/10] Batch [300/391] Loss D: 0.3047, Loss G: 3.1211
# Your task: fix all 10 bugs until training runs and samples look reasonable.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some images
with torch.no_grad():
    z = torch.randn(16, z_dim, device=device) # Generate 16 images
    generated_images = Gnet(z).detach().cpu()

# Denormalize the images
generated_images = generated_images * 0.5 + 0.5

# Display the images
fig, axes = plt.subplots(4, 4, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    img = np.transpose(generated_images[i].numpy(), (1, 2, 0))
    ax.imshow(img)
    ax.axis('off')
plt.show()
